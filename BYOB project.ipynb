# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from sqlalchemy import create_engine


# File to Load (Remember to Change These)
data = "BYOB_data.csv"

# Read Purchasing File and store into Pandas data frame
beer_data = pd.read_csv(data)
beer_data.head()
# Out:
#   id  brewery_id                    name  cat_id   categories  style_id  \
# 0  1         812             Hocus Pocus    11.0  Other Style     116.0
# 1  2         264       Grimbergen Blonde    -1.0          NaN      -1.0
# 2  3         779  Widdershins Barleywine    -1.0          NaN      -1.0
# 3  4         287                 Lucifer    -1.0          NaN      -1.0
# 4  5        1056                  Bitter    -1.0          NaN      -1.0
#
#                                style  abv  \
# 0  Light American Wheat Ale or Lager  4.5
# 1                                NaN  6.7
# 2                                NaN  9.1
# 3                                NaN  8.5
# 4                                NaN  4.0
#
#                                     beer_description  \
# 0  Our take on a classic summer ale.  A toast to ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
beer_data = beer_data.dropna(how="any")
beer_data.head()
# Out:
#     id  brewery_id                  name  cat_id              categories  \
# 0    1         812           Hocus Pocus    11.0             Other Style
# 26  27         878  Full Moon Winter Ale     5.0  Belgian and French Ale
# 27  28         935             Odell IPA     3.0      North American Ale
# 28  29        1271    Ornery Amber Lager     8.0    North American Lager
# 29  30         935      Cutthroat Porter     2.0               Irish Ale
#
#     style_id                              style  abv  \
# 0      116.0  Light American Wheat Ale or Lager  4.5
# 26      72.0           Other Belgian-Style Ales  5.6
# 27      31.0      American-Style India Pale Ale  7.0
# 28      95.0               American-Style Lager  0.0
# 29      25.0                             Porter  4.8
#
#                                      beer_description  \
# 0   Our take on a classic summer ale.  A toast to ...
# 26  This full-bodied ale is brewed with roasted ma...
# ...

# %%
organized_df = beer_data[["id", "brewery_id", "name", "categories", "style", "abv", 
                          "beer_description", "brewery_name", "address1", "city", "state", 
                          "code", "country", "latitude", "longitude"]]
organized_df.head()
# Out:
#     id  brewery_id                  name              categories  \
# 0    1         812           Hocus Pocus             Other Style
# 26  27         878  Full Moon Winter Ale  Belgian and French Ale
# 27  28         935             Odell IPA      North American Ale
# 28  29        1271    Ornery Amber Lager    North American Lager
# 29  30         935      Cutthroat Porter               Irish Ale
#
#                                 style  abv  \
# 0   Light American Wheat Ale or Lager  4.5
# 26           Other Belgian-Style Ales  5.6
# 27      American-Style India Pale Ale  7.0
# 28               American-Style Lager  0.0
# 29                             Porter  4.8
#
#                                      beer_description  \
# 0   Our take on a classic summer ale.  A toast to ...
# 26  This full-bodied ale is brewed with roasted ma...
# 27  We took the traditional IPA, originally shippe...
# 28  Ornery Amber is brewed with a blend of the fin...
# ...

# %%
organized_df.set_index("id")
# Out:
#       brewery_id                                  name  \
# id
# 1            812                           Hocus Pocus
# 27           878                  Full Moon Winter Ale
# 28           935                             Odell IPA
# 29          1271                    Ornery Amber Lager
# 30           935                      Cutthroat Porter
# 31          1271               Maple Nut Brown Ale Ale
# 40          1307                         Quelque Chose
# 43           723                    Maracaibo Especial
# 45           723                       Calabaza Blanca
# 58          1221                          Furious Beer
# 59          1221                           Bender Beer
# 63           935                         Isolation Ale
# 71           161                       Nut Cracker Ale
# 80          1202                   Weizengold Hefefein
# 103         1260         Robert the Bruce Scottish Ale
# 124          441                         Buzzsaw Brown
# ...

# %%
organized_df.dtypes
# Out:
# id                   object
# brewery_id            int64
# name                 object
# categories           object
# style                object
# abv                 float64
# beer_description     object
# brewery_name         object
# address1             object
# city                 object
# state                object
# code                 object
# country              object
# latitude            float64
# longitude           float64
# dtype: object

# %%
connection_string = "postgres:HLlh5689@@localhost:5432/Beerdatabase"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['beer_info']

# %%
organized_df.to_sql(name='beer_info', con=engine, if_exists='append', index=False)
